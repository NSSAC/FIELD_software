# %%
from glob import glob
from kbviz import plot
import pandas as pd
from pdb import set_trace
from re import sub

# %%
farms = pd.read_csv('../results/farms_with_bounds.csv')
network = pd.read_parquet('../work/cell_farm_bipartite_edges.parquet')

# %%
dlist = glob('../work/worker_farm_mw*.csv')
dflist = []
for fname in dlist:
    data = pd.read_csv(fname)
    miles = sub('.*mi', '', sub('.csv', '', fname))
    min_workers = sub('.*_mw', '', sub('_mi.*', '', fname))
    print('miles:', miles, 'min_workers:', min_workers)
    data['miles'] = miles
    data['min_workers'] = min_workers
    dflist.append(data)

df = pd.concat(dflist)
# Out:
# miles: 60 min_workers: 0
# miles: 80 min_workers: 0
# miles: 60 min_workers: 1
# miles: 20 min_workers: 0
# miles: 40 min_workers: 0
# miles: 100 min_workers: 0
# miles: 10 min_workers: 0
# miles: 80 min_workers: 1
# miles: 100 min_workers: 1
# miles: 40 min_workers: 1

# %%
df = df.astype({'miles': float, 'min_workers': int})

# %%
total_farms = farms.shape[0]
assigned_farms = df.groupby(['min_workers', 'miles']).farm.nunique().reset_index()
assigned_farms['perc'] = assigned_farms['farm'] / total_farms * 100

# %%
assigned_farms
# Out:
#    min_workers  miles   farm        perc
# 0            0   10.0  35909   72.696170
# 1            0   20.0  39849   80.672524
# 2            0   40.0  42343   85.721516
# 3            0   60.0  44023   89.122601
# 4            0   80.0  45436   91.983157
# 5            0  100.0  46449   94.033930
# 6            1   40.0  49387   99.981780
# 7            1   60.0  49396  100.000000
# 8            1   80.0  49396  100.000000
# 9            1  100.0  49396  100.000000

# %%
fig = plot.Fig(x=5, y=4)
sp = plot.Subplot(fig=fig)

pe = plot.Lineplot(subplot=sp, data=assigned_farms,
                   x='miles', y='perc', 
                   hue='min_workers', hue_order=[0, 1])
sp.xlabel('Max. miles between farm and residence')
sp.ylabel(r'\% of farms assigned agricultural worker')
fig.savefig('../work/tp.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /project/bii_nssac/people/aa5ts/conda-envs/ldt/lib/python3.11/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /project/bii_nssac/people/aa5ts/conda-envs/ldt/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# ...
